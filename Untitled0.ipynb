# %% [markdown]
# <a href="https://colab.research.google.com/github/Francisco99-gm/examen-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Programa1
a=float (input("Obtener el valor de a:"))
b=float (input("Obtener el valor de b:"))
c=float (input("Obtener el valor de c:"))

dis= (b**2)-4*a*c

while (dis<0):
  print("Error en el discriminante tiene que ser positivo ")
  
a=float (input("Obtener el valor de a:"))
b=float (input("Obtener el valor de b:"))
c=float (input("Obtener el valor de c:"))

dis=(b**2)-4*a*c

if dis==0:
    x=-b/(2*a)
    print("X solo tiene una solucion =",x)
else:
  x1=(-b+(dis**0.5))/(2*a)
  x2=(-b-(dis**0.5))/(2*a)
  print("la primera soluicion de X =" ,x1)
  print("la primer solucion de X =" .x2)

  
print("fin del programa")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# Error en el discriminante tiene que ser positivo
# ...

# %%
#programa2
def funcion(x):
  x= (x**2)+(3*x)+3
  return x
  x = int (input("Ingrese el valor de x:"))
  x = funcion(x)
  print("El valor de la funcion es:" ,x,)

  cont = -4
  while  (cont < 4):
    cont = cont + 1
    x = (cont**2)+(3*cont)+3
    print(cont, "valor de x:" ,x)
    if (x > 30):
      print("valor maximo de 30")



milista=[4,2,1,4,7,13,19]
